# %% [markdown]
# <a href="https://colab.research.google.com/github/souzaamanda/imersao-python-alura/blob/main/Imers%C3%A3o_Python_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Variação % Dia  \
# 0  USIM5 2024-01-26         9.50          5.20          0.0520
# 1  CMIN3 2024-01-26         6.82          2.40          0.0240
# 2  PETR3 2024-01-26        41.96          2.19          0.0219
# 3  SUZB3 2024-01-26        52.91          2.04          0.0204
# 4  CPFE3 2024-01-26        37.10          2.03          0.0203
# 5  PRIO3 2024-01-26        45.69          1.98          0.0198
# 6  PETR4 2024-01-26        39.96          1.73          0.0173
# 7  VALE3 2024-01-26        69.50          1.66          0.0166
# 8  MULT3 2024-01-26        28.19          1.58          0.0158
# 9  ITUB4 2024-01-26        32.81          1.48          0.0148
#
#    Valor Inicial Dia  Var. Ações Dia Resultado Dia  Var. Sem. (%)  \
# 0           9.030418    2.418897e+08         Subiu          11.76
# 1           6.660156    1.775160e+08         Subiu           2.40
# 2          41.060769    2.140059e+09         Subiu           7.73
# 3          51.852215    7.229463e+08         Subiu           2.14
# 4          36.361854    1.385740e+08         Subiu           2.49
# 5          44.802903    7.096875e+08         Subiu           2.42
# 6          39.280448    3.103136e+09         Subiu           6.47
# 7          68.365139    4.762927e+09         Subiu           2.06
# 8          27.751526    1.177327e+08         Subiu           2.03
# 9          32.331494    2.297592e+09         Subiu          -0.39
#
#    Variação % Sem.  ...  Var. Ações 12M  Resultado 12M Val. Mín  Val. Máx  \
# 0           0.1176  ...    6.738901e+08          Subiu     9.18      9.56
# 1           0.0240  ...    2.543452e+09          Subiu     6.66      6.86
# 2           0.0773  ...    4.361654e+10          Subiu    40.81     42.34
# 3           0.0214  ...    5.735331e+09          Subiu    51.89     53.17
# 4           0.0249  ...    1.194474e+09          Subiu    36.37     37.32
# 5           0.0242  ...    2.732644e+09          Subiu    44.25     45.69
# 6           0.0647  ...    8.890296e+10          Subiu    38.91     40.09
# 7           0.0206  ...   -8.955313e+10         Desceu    67.50     69.81
# 8           0.0203  ...    1.465985e+09          Subiu    27.71     28.36
# 9          -0.0039  ...    4.019184e+10          Subiu    32.35     32.91
#
#      Volume  Quantidade de ações  Nome da empresa          Segmento  \
# 0  319,16 M            515117391         Usiminas        Siderurgia
# 1   32,65 M           1110559345    CSN Mineração         Mineração
# 2  436,69 M           2379877655        Petrobras          Petróleo
# 3  162,55 M            683452836           Suzano  Papel e Celulose
# 4   73,42 M            187732538     CPFL Energia           Energia
# 5  319,92 M            800010734         PetroRio          Petróleo
# 6    1,64 B           4566445852        Petrobras          Petróleo
# 7    1,89 B           4196924316             Vale         Mineração
# 8  104,16 M            268505432        Multiplan  Shopping Centers
# 9   473,2 M           4801593832    Itaú Unibanco             Banco
#
#    Idade (anos)            Cat_Idade
# 0            60  Entre 50 e 100 anos
# 1             8     Menos de 50 anos
# 2            69  Entre 50 e 100 anos
# 3            94  Entre 50 e 100 anos
# 4           109     Mais de 100 anos
# 5             9     Menos de 50 anos
# 6            69  Entre 50 e 100 anos
# 7            79  Entre 50 e 100 anos
# 8            48     Menos de 50 anos
# 9            13     Menos de 50 anos
#
# [10 rows x 36 columns]

# %%
df_total_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Imersão Python - Tabela de ações.xlsx",sheet_name="ChatGPT")
df_chatgpt
# Out:
#              Empresa           Segmento  Idade
# 0           Usiminas         Siderurgia     60
# 1      CSN Mineração          Mineração      8
# 2          Petrobras           Petróleo     69
# 3             Suzano   Papel e Celulose     94
# 4       CPFL Energia            Energia    109
# ..               ...                ...    ...
# 76  Carrefour Brasil             Varejo     37
# 77       Casas Bahia             Varejo     95
# 78          Localiza  Aluguel de Carros     49
# 79               CVC            Turismo     50
# 80               GOL            Aviação     20
#
# [81 rows x 3 columns]
